# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
from citipy import citipy

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
print (lat_lngs)
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# []
# 648

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

#query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# set up lists to hold api reponse
api_cities = []
latitude = []
longitude = []
temperature_max = []
humidity = []
cloudiness = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each

#Header of print log
print (f'Beginning Data Retrival')

#Variables to set initial values of record and set of print log
record_number = 0
set_number = 1

#Loop through each city from Cities list
for city in cities:
  
      #increments record and set count up until 50, get out of the loop and start the next set of count
    if (record_number > 50):
        record_number = 0
        set_number = set_number + 1
 
    print(f'Processing Record {record_number} Set of {set_number} | {city}')
    record_number = record_number + 1
    
    city_url = query_url + city
    print (city_url) #print each individual URL the API will call and get response from
    
    response = requests.get(query_url + city).json()
       
    if response ['cod'] == 200: #checks if response is sucessfull, if other than 200, skip code below
            api_cities.append(response['name'])
            latitude.append(response['coord']['lat'])
            longitude.append(response['coord']['lon'])
            temperature_max.append(response['main']['temp_max'])
            humidity.append(response['main']['humidity'])
            cloudiness.append(response['clouds']['all'])
            wind_speed.append(response['wind']['speed'])
# Out:
# Beginning Data Retrival
# Processing Record 0 Set of 1 | jilin
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=jilin
# Processing Record 1 Set of 1 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=touros
# Processing Record 2 Set of 1 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=avera
# Processing Record 3 Set of 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hermanus
# Processing Record 4 Set of 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=provideniya
# Processing Record 5 Set of 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bengkulu
# Processing Record 6 Set of 1 | tunxi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tunxi
# Processing Record 7 Set of 1 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=la ronge
# Processing Record 8 Set of 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tasiilaq
# Processing Record 9 Set of 1 | paracuru
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=paracuru
# Processing Record 10 Set of 1 | kapchorwa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kapchorwa
# Processing Record 11 Set of 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=severo-kurilsk
# Processing Record 12 Set of 1 | boffa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=boffa
# Processing Record 13 Set of 1 | jiroft
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=jiroft
# Processing Record 14 Set of 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=punta arenas
# Processing Record 15 Set of 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=codrington
# Processing Record 16 Set of 1 | seydisehir
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=seydisehir
# Processing Record 17 Set of 1 | lahij
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lahij
# Processing Record 18 Set of 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=khatanga
# Processing Record 19 Set of 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=chokurdakh
# Processing Record 20 Set of 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=albany
# Processing Record 21 Set of 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=jamestown
# Processing Record 22 Set of 1 | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=moose factory
# Processing Record 23 Set of 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=barrow
# Processing Record 24 Set of 1 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=diego de almagro
# Processing Record 25 Set of 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lebu
# Processing Record 26 Set of 1 | henderson
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=henderson
# Processing Record 27 Set of 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kavieng
# Processing Record 28 Set of 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hobart
# Processing Record 29 Set of 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=katsuura
# Processing Record 30 Set of 1 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=coihaique
# Processing Record 31 Set of 1 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=east london
# Processing Record 32 Set of 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=rikitea
# Processing Record 33 Set of 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=thompson
# Processing Record 34 Set of 1 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ngunguru
# Processing Record 35 Set of 1 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=guerrero negro
# Processing Record 36 Set of 1 | smithers
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=smithers
# Processing Record 37 Set of 1 | guasca
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=guasca
# Processing Record 38 Set of 1 | el alto
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=el alto
# Processing Record 39 Set of 1 | bud
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bud
# Processing Record 40 Set of 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=vaini
# Processing Record 41 Set of 1 | acaponeta
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=acaponeta
# Processing Record 42 Set of 1 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kamenskoye
# Processing Record 43 Set of 1 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=antofagasta
# Processing Record 44 Set of 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tuktoyaktuk
# Processing Record 45 Set of 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mataura
# Processing Record 46 Set of 1 | krasnoshchekovo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=krasnoshchekovo
# Processing Record 47 Set of 1 | barguzin
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=barguzin
# Processing Record 48 Set of 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=atuona
# Processing Record 49 Set of 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ushuaia
# Processing Record 50 Set of 1 | maun
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=maun
# Processing Record 0 Set of 2 | quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=quelimane
# Processing Record 1 Set of 2 | bowen
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bowen
# Processing Record 2 Set of 2 | sayyan
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sayyan
# Processing Record 3 Set of 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kapaa
# Processing Record 4 Set of 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=busselton
# Processing Record 5 Set of 2 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bonavista
# Processing Record 6 Set of 2 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=pangnirtung
# Processing Record 7 Set of 2 | lingyuan
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lingyuan
# Processing Record 8 Set of 2 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=caravelas
# Processing Record 9 Set of 2 | feijo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=feijo
# Processing Record 10 Set of 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=amderma
# Processing Record 11 Set of 2 | wajir
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=wajir
# Processing Record 12 Set of 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bethel
# Processing Record 13 Set of 2 | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kununurra
# Processing Record 14 Set of 2 | noumea
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=noumea
# Processing Record 15 Set of 2 | nago
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=nago
# Processing Record 16 Set of 2 | las varas
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=las varas
# Processing Record 17 Set of 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=torbay
# Processing Record 18 Set of 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=butaritari
# Processing Record 19 Set of 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=avarua
# Processing Record 20 Set of 2 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=port hardy
# Processing Record 21 Set of 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=port alfred
# Processing Record 22 Set of 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=arraial do cabo
# Processing Record 23 Set of 2 | guilin
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=guilin
# Processing Record 24 Set of 2 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mandalgovi
# Processing Record 25 Set of 2 | niteroi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=niteroi
# Processing Record 26 Set of 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=upernavik
# Processing Record 27 Set of 2 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ketchikan
# Processing Record 28 Set of 2 | medea
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=medea
# Processing Record 29 Set of 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=faanui
# Processing Record 30 Set of 2 | soe
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=soe
# Processing Record 31 Set of 2 | alyangula
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=alyangula
# Processing Record 32 Set of 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bluff
# Processing Record 33 Set of 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hilo
# Processing Record 34 Set of 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kodiak
# Processing Record 35 Set of 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=new norfolk
# Processing Record 36 Set of 2 | juneau
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=juneau
# Processing Record 37 Set of 2 | oussouye
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=oussouye
# Processing Record 38 Set of 2 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=raudeberg
# Processing Record 39 Set of 2 | tripoli
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tripoli
# Processing Record 40 Set of 2 | sibolga
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sibolga
# Processing Record 41 Set of 2 | la baule-escoublac
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=la baule-escoublac
# Processing Record 42 Set of 2 | araouane
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=araouane
# Processing Record 43 Set of 2 | palimbang
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=palimbang
# Processing Record 44 Set of 2 | buchanan
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=buchanan
# Processing Record 45 Set of 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ribeira grande
# Processing Record 46 Set of 2 | turkmenabat
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=turkmenabat
# Processing Record 47 Set of 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cabo san lucas
# Processing Record 48 Set of 2 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tilichiki
# Processing Record 49 Set of 2 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=blagoyevo
# Processing Record 50 Set of 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=pevek
# Processing Record 0 Set of 3 | ati
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ati
# Processing Record 1 Set of 3 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=puerto ayora
# Processing Record 2 Set of 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=nikolskoye
# Processing Record 3 Set of 3 | jaumave
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=jaumave
# Processing Record 4 Set of 3 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=salinopolis
# Processing Record 5 Set of 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=longyearbyen
# Processing Record 6 Set of 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=georgetown
# Processing Record 7 Set of 3 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=port hedland
# Processing Record 8 Set of 3 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=los llanos de aridane
# Processing Record 9 Set of 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tiksi
# Processing Record 10 Set of 3 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=champerico
# Processing Record 11 Set of 3 | viedma
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=viedma
# Processing Record 12 Set of 3 | porbandar
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=porbandar
# Processing Record 13 Set of 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bambous virieux
# Processing Record 14 Set of 3 | ous
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ous
# Processing Record 15 Set of 3 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=seoul
# Processing Record 16 Set of 3 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=beloha
# Processing Record 17 Set of 3 | maumere
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=maumere
# Processing Record 18 Set of 3 | ulety
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ulety
# Processing Record 19 Set of 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bathsheba
# Processing Record 20 Set of 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bredasdorp
# Processing Record 21 Set of 3 | naryan-mar
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=naryan-mar
# Processing Record 22 Set of 3 | havelock
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=havelock
# Processing Record 23 Set of 3 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=attawapiskat
# Processing Record 24 Set of 3 | ossora
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ossora
# Processing Record 25 Set of 3 | grand island
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=grand island
# Processing Record 26 Set of 3 | tyukalinsk
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tyukalinsk
# Processing Record 27 Set of 3 | dali
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=dali
# Processing Record 28 Set of 3 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=nanortalik
# Processing Record 29 Set of 3 | antsla
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=antsla
# Processing Record 30 Set of 3 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bilibino
# Processing Record 31 Set of 3 | ballina
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ballina
# Processing Record 32 Set of 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=saint-philippe
# Processing Record 33 Set of 3 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=taolanaro
# Processing Record 34 Set of 3 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hami
# Processing Record 35 Set of 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=vardo
# Processing Record 36 Set of 3 | urzhum
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=urzhum
# Processing Record 37 Set of 3 | la macarena
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=la macarena
# Processing Record 38 Set of 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mahebourg
# Processing Record 39 Set of 3 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ostrovnoy
# Processing Record 40 Set of 3 | buariki
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=buariki
# Processing Record 41 Set of 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=norman wells
# Processing Record 42 Set of 3 | colares
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=colares
# Processing Record 43 Set of 3 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=olafsvik
# Processing Record 44 Set of 3 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=prince rupert
# Processing Record 45 Set of 3 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cayenne
# Processing Record 46 Set of 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=saint george
# Processing Record 47 Set of 3 | marienburg
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=marienburg
# Processing Record 48 Set of 3 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cherskiy
# Processing Record 49 Set of 3 | mrirt
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mrirt
# Processing Record 50 Set of 3 | vestbygda
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=vestbygda
# Processing Record 0 Set of 4 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=haines junction
# Processing Record 1 Set of 4 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sioux lookout
# Processing Record 2 Set of 4 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=geraldton
# Processing Record 3 Set of 4 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hasaki
# Processing Record 4 Set of 4 | sulzbach-rosenberg
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sulzbach-rosenberg
# Processing Record 5 Set of 4 | kenora
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kenora
# Processing Record 6 Set of 4 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=richards bay
# Processing Record 7 Set of 4 | mitu
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mitu
# Processing Record 8 Set of 4 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=coquimbo
# Processing Record 9 Set of 4 | jeremie
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=jeremie
# Processing Record 10 Set of 4 | ust-ishim
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ust-ishim
# Processing Record 11 Set of 4 | eidsvag
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=eidsvag
# Processing Record 12 Set of 4 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kavaratti
# Processing Record 13 Set of 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=qaanaaq
# Processing Record 14 Set of 4 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sisimiut
# Processing Record 15 Set of 4 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=oktyabrskiy
# Processing Record 16 Set of 4 | kondoa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kondoa
# Processing Record 17 Set of 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=port elizabeth
# Processing Record 18 Set of 4 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=narsaq
# Processing Record 19 Set of 4 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=northam
# Processing Record 20 Set of 4 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=vila velha
# Processing Record 21 Set of 4 | zhanatas
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=zhanatas
# Processing Record 22 Set of 4 | kupang
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kupang
# Processing Record 23 Set of 4 | biak
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=biak
# Processing Record 24 Set of 4 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=manavalakurichi
# Processing Record 25 Set of 4 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=praia da vitoria
# Processing Record 26 Set of 4 | forssa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=forssa
# Processing Record 27 Set of 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=carnarvon
# Processing Record 28 Set of 4 | porterville
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=porterville
# Processing Record 29 Set of 4 | ternate
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ternate
# Processing Record 30 Set of 4 | kintampo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kintampo
# Processing Record 31 Set of 4 | khonuu
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=khonuu
# Processing Record 32 Set of 4 | cayeli
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cayeli
# Processing Record 33 Set of 4 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=deputatskiy
# Processing Record 34 Set of 4 | mingaora
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mingaora
# Processing Record 35 Set of 4 | escarcega
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=escarcega
# Processing Record 36 Set of 4 | rio cuarto
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=rio cuarto
# Processing Record 37 Set of 4 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=acapulco
# Processing Record 38 Set of 4 | kedrovyy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kedrovyy
# Processing Record 39 Set of 4 | marzuq
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=marzuq
# Processing Record 40 Set of 4 | aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=aykhal
# Processing Record 41 Set of 4 | verkhniy baskunchak
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=verkhniy baskunchak
# Processing Record 42 Set of 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=iqaluit
# Processing Record 43 Set of 4 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tabiauea
# Processing Record 44 Set of 4 | visby
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=visby
# Processing Record 45 Set of 4 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=skalistyy
# Processing Record 46 Set of 4 | kutum
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kutum
# Processing Record 47 Set of 4 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lorengau
# Processing Record 48 Set of 4 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=atar
# Processing Record 49 Set of 4 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=castro
# Processing Record 50 Set of 4 | aksay
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=aksay
# Processing Record 0 Set of 5 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tecoanapa
# Processing Record 1 Set of 5 | kondagaon
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kondagaon
# Processing Record 2 Set of 5 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=batagay-alyta
# Processing Record 3 Set of 5 | tarancon
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tarancon
# Processing Record 4 Set of 5 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tura
# Processing Record 5 Set of 5 | josanicka banja
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=josanicka banja
# Processing Record 6 Set of 5 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=rawson
# Processing Record 7 Set of 5 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=saint-georges
# Processing Record 8 Set of 5 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=barentsburg
# Processing Record 9 Set of 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=san patricio
# Processing Record 10 Set of 5 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=luderitz
# Processing Record 11 Set of 5 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lavrentiya
# Processing Record 12 Set of 5 | majene
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=majene
# Processing Record 13 Set of 5 | ippy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ippy
# Processing Record 14 Set of 5 | choszczno
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=choszczno
# Processing Record 15 Set of 5 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=yellowknife
# Processing Record 16 Set of 5 | wajima
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=wajima
# Processing Record 17 Set of 5 | emet
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=emet
# Processing Record 18 Set of 5 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hervey bay
# Processing Record 19 Set of 5 | bahia blanca
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bahia blanca
# Processing Record 20 Set of 5 | goundi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=goundi
# Processing Record 21 Set of 5 | sorvag
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sorvag
# Processing Record 22 Set of 5 | praia
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=praia
# Processing Record 23 Set of 5 | riyadh
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=riyadh
# Processing Record 24 Set of 5 | padang
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=padang
# Processing Record 25 Set of 5 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kloulklubed
# Processing Record 26 Set of 5 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=laguna
# Processing Record 27 Set of 5 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=umzimvubu
# Processing Record 28 Set of 5 | pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=pochutla
# Processing Record 29 Set of 5 | talara
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=talara
# Processing Record 30 Set of 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=oranjemund
# Processing Record 31 Set of 5 | terenga
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=terenga
# Processing Record 32 Set of 5 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=skibbereen
# Processing Record 33 Set of 5 | torbat-e jam
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=torbat-e jam
# Processing Record 34 Set of 5 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=fortuna
# Processing Record 35 Set of 5 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=yar-sale
# Processing Record 36 Set of 5 | griffith
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=griffith
# Processing Record 37 Set of 5 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=meulaboh
# Processing Record 38 Set of 5 | the valley
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=the valley
# Processing Record 39 Set of 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=san cristobal
# Processing Record 40 Set of 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=alofi
# Processing Record 41 Set of 5 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=nelson bay
# Processing Record 42 Set of 5 | cachoeirinha
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cachoeirinha
# Processing Record 43 Set of 5 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sur
# Processing Record 44 Set of 5 | chamba
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=chamba
# Processing Record 45 Set of 5 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=saint-augustin
# Processing Record 46 Set of 5 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=saint-pierre
# Processing Record 47 Set of 5 | kanashevo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kanashevo
# Processing Record 48 Set of 5 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ponta do sol
# Processing Record 49 Set of 5 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=esperance
# Processing Record 50 Set of 5 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=grindavik
# Processing Record 0 Set of 6 | usinsk
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=usinsk
# Processing Record 1 Set of 6 | chinsali
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=chinsali
# Processing Record 2 Set of 6 | ploemeur
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ploemeur
# Processing Record 3 Set of 6 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=illoqqortoormiut
# Processing Record 4 Set of 6 | morondava
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=morondava
# Processing Record 5 Set of 6 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=souillac
# Processing Record 6 Set of 6 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=saskylakh
# Processing Record 7 Set of 6 | merauke
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=merauke
# Processing Record 8 Set of 6 | fomboni
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=fomboni
# Processing Record 9 Set of 6 | korcula
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=korcula
# Processing Record 10 Set of 6 | dwarka
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=dwarka
# Processing Record 11 Set of 6 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=dikson
# Processing Record 12 Set of 6 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=victoria
# Processing Record 13 Set of 6 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=coahuayana
# Processing Record 14 Set of 6 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cape town
# Processing Record 15 Set of 6 | moindou
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=moindou
# Processing Record 16 Set of 6 | umm durman
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=umm durman
# Processing Record 17 Set of 6 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=atambua
# Processing Record 18 Set of 6 | yanliang
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=yanliang
# Processing Record 19 Set of 6 | neiafu
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=neiafu
# Processing Record 20 Set of 6 | great bend
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=great bend
# Processing Record 21 Set of 6 | digras
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=digras
# Processing Record 22 Set of 6 | beruwala
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=beruwala
# Processing Record 23 Set of 6 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=pisco
# Processing Record 24 Set of 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sitka
# Processing Record 25 Set of 6 | wonthaggi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=wonthaggi
# Processing Record 26 Set of 6 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=isangel
# Processing Record 27 Set of 6 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=grand river south east
# Processing Record 28 Set of 6 | russell
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=russell
# Processing Record 29 Set of 6 | chulakivka
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=chulakivka
# Processing Record 30 Set of 6 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=komsomolskiy
# Processing Record 31 Set of 6 | tromso
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tromso
# Processing Record 32 Set of 6 | najran
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=najran
# Processing Record 33 Set of 6 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cockburn town
# Processing Record 34 Set of 6 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sungaipenuh
# Processing Record 35 Set of 6 | sire
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sire
# Processing Record 36 Set of 6 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bay roberts
# Processing Record 37 Set of 6 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bundaberg
# Processing Record 38 Set of 6 | panalingaan
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=panalingaan
# Processing Record 39 Set of 6 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hamilton
# Processing Record 40 Set of 6 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=leningradskiy
# Processing Record 41 Set of 6 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lac du bonnet
# Processing Record 42 Set of 6 | buzdyak
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=buzdyak
# Processing Record 43 Set of 6 | kamaishi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kamaishi
# Processing Record 44 Set of 6 | springbok
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=springbok
# Processing Record 45 Set of 6 | dajal
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=dajal
# Processing Record 46 Set of 6 | yoichi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=yoichi
# Processing Record 47 Set of 6 | hihifo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hihifo
# Processing Record 48 Set of 6 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sentyabrskiy
# Processing Record 49 Set of 6 | fort saint john
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=fort saint john
# Processing Record 50 Set of 6 | khani
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=khani
# Processing Record 0 Set of 7 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=pacific grove
# Processing Record 1 Set of 7 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=vila franca do campo
# Processing Record 2 Set of 7 | gardan diwal
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=gardan diwal
# Processing Record 3 Set of 7 | fort saint james
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=fort saint james
# Processing Record 4 Set of 7 | beterou
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=beterou
# Processing Record 5 Set of 7 | nakhon si thammarat
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=nakhon si thammarat
# Processing Record 6 Set of 7 | santiago del estero
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=santiago del estero
# Processing Record 7 Set of 7 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=nizhneyansk
# Processing Record 8 Set of 7 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=turukhansk
# Processing Record 9 Set of 7 | fairbanks
# ...
# Processing Record 33 Set of 11 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lagoa
# Processing Record 34 Set of 11 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=broken hill
# Processing Record 35 Set of 11 | kawana waters
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kawana waters
# Processing Record 36 Set of 11 | carlos chagas
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=carlos chagas
# Processing Record 37 Set of 11 | duluth
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=duluth
# Processing Record 38 Set of 11 | ivanovskoye
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ivanovskoye
# Processing Record 39 Set of 11 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=port macquarie
# Processing Record 40 Set of 11 | mecca
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mecca
# Processing Record 41 Set of 11 | pontian kecil
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=pontian kecil
# Processing Record 42 Set of 11 | aljezur
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=aljezur
# Processing Record 43 Set of 11 | safaga
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=safaga
# Processing Record 44 Set of 11 | igrim
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=igrim
# Processing Record 45 Set of 11 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=half moon bay
# Processing Record 46 Set of 11 | miyako
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=miyako
# Processing Record 47 Set of 11 | chifeng
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=chifeng
# Processing Record 48 Set of 11 | dukat
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=dukat
# Processing Record 49 Set of 11 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lompoc
# Processing Record 50 Set of 11 | aswan
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=aswan
# Processing Record 0 Set of 12 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=zhangjiakou
# Processing Record 1 Set of 12 | eforie
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=eforie
# Processing Record 2 Set of 12 | labytnangi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=labytnangi
# Processing Record 3 Set of 12 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=honningsvag
# Processing Record 4 Set of 12 | hanstholm
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hanstholm
# Processing Record 5 Set of 12 | ust-koksa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=ust-koksa
# Processing Record 6 Set of 12 | praya
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=praya
# Processing Record 7 Set of 12 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=egvekinot
# Processing Record 8 Set of 12 | amga
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=amga
# Processing Record 9 Set of 12 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=gat
# Processing Record 10 Set of 12 | lar gerd
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lar gerd
# Processing Record 11 Set of 12 | jalgaon
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=jalgaon
# Processing Record 12 Set of 12 | honiara
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=honiara
# Processing Record 13 Set of 12 | halalo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=halalo
# Processing Record 14 Set of 12 | barroualie
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=barroualie
# Processing Record 15 Set of 12 | kanigoro
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kanigoro
# Processing Record 16 Set of 12 | teguise
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=teguise
# Processing Record 17 Set of 12 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=klaksvik
# Processing Record 18 Set of 12 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=portland
# Processing Record 19 Set of 12 | lolua
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=lolua
# Processing Record 20 Set of 12 | matagami
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=matagami
# Processing Record 21 Set of 12 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=taoudenni
# Processing Record 22 Set of 12 | bayanday
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bayanday
# Processing Record 23 Set of 12 | igarka
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=igarka
# Processing Record 24 Set of 12 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kemijarvi
# Processing Record 25 Set of 12 | barranca
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=barranca
# Processing Record 26 Set of 12 | bestobe
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=bestobe
# Processing Record 27 Set of 12 | falealupo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=falealupo
# Processing Record 28 Set of 12 | huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=huarmey
# Processing Record 29 Set of 12 | broceni
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=broceni
# Processing Record 30 Set of 12 | eureka
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=eureka
# Processing Record 31 Set of 12 | price
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=price
# Processing Record 32 Set of 12 | santa marta de tormes
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=santa marta de tormes
# Processing Record 33 Set of 12 | stargard szczecinski
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=stargard szczecinski
# Processing Record 34 Set of 12 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=abu samrah
# Processing Record 35 Set of 12 | isfana
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=isfana
# Processing Record 36 Set of 12 | hoshcha
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=hoshcha
# Processing Record 37 Set of 12 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=oktyabrskoye
# Processing Record 38 Set of 12 | qinzhou
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=qinzhou
# Processing Record 39 Set of 12 | parras
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=parras
# Processing Record 40 Set of 12 | mombasa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mombasa
# Processing Record 41 Set of 12 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=quatre cocos
# Processing Record 42 Set of 12 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=necochea
# Processing Record 43 Set of 12 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=klyuchi
# Processing Record 44 Set of 12 | arcachon
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=arcachon
# Processing Record 45 Set of 12 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=flinders
# Processing Record 46 Set of 12 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kruisfontein
# Processing Record 47 Set of 12 | pangody
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=pangody
# Processing Record 48 Set of 12 | eyl
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=eyl
# Processing Record 49 Set of 12 | katherine
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=katherine
# Processing Record 50 Set of 12 | cervo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=cervo
# Processing Record 0 Set of 13 | charagua
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=charagua
# Processing Record 1 Set of 13 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=severo-yeniseyskiy
# Processing Record 2 Set of 13 | uusikaupunki
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=uusikaupunki
# Processing Record 3 Set of 13 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=axim
# Processing Record 4 Set of 13 | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=erenhot
# Processing Record 5 Set of 13 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=san policarpo
# Processing Record 6 Set of 13 | rungata
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=rungata
# Processing Record 7 Set of 13 | siderno
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=siderno
# Processing Record 8 Set of 13 | rivera
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=rivera
# Processing Record 9 Set of 13 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=husavik
# Processing Record 10 Set of 13 | tarauaca
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=tarauaca
# Processing Record 11 Set of 13 | rohatyn
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=rohatyn
# Processing Record 12 Set of 13 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sao filipe
# Processing Record 13 Set of 13 | garissa
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=garissa
# Processing Record 14 Set of 13 | maebaru
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=maebaru
# Processing Record 15 Set of 13 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=zhanaozen
# Processing Record 16 Set of 13 | manaure
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=manaure
# Processing Record 17 Set of 13 | swan hill
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=swan hill
# Processing Record 18 Set of 13 | zhongxing
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=zhongxing
# Processing Record 19 Set of 13 | mazamet
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mazamet
# Processing Record 20 Set of 13 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=broome
# Processing Record 21 Set of 13 | djibo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=djibo
# Processing Record 22 Set of 13 | middle island
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=middle island
# Processing Record 23 Set of 13 | victoriaville
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=victoriaville
# Processing Record 24 Set of 13 | kyra
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=kyra
# Processing Record 25 Set of 13 | baraboo
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=baraboo
# Processing Record 26 Set of 13 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=jalu
# Processing Record 27 Set of 13 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=angoche
# Processing Record 28 Set of 13 | emba
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=emba
# Processing Record 29 Set of 13 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=mount gambier
# Processing Record 30 Set of 13 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=dongsheng
# Processing Record 31 Set of 13 | awbari
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=awbari
# Processing Record 32 Set of 13 | carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=carutapera
# Processing Record 33 Set of 13 | xiangxiang
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=xiangxiang
# Processing Record 34 Set of 13 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=sao joao da barra
# Processing Record 35 Set of 13 | zilupe
# http://api.openweathermap.org/data/2.5/weather?appid=3567360c8a78f247cb21275118a6ae30&units=metric&q=zilupe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print (len(api_cities))
print (len(latitude))
print (len(longitude))
print (len(humidity))
print (len(temperature_max))
print (len(cloudiness))
print (len(wind_speed))
# Out:
# 584
# 584
# 584
# 584
# 584
# 584
# 584

# %%
weatherpy_df = pd.DataFrame({"City": api_cities,
                           "Latitude": latitude,
                           "Longitude": longitude,
                           "Humidity": humidity,
                           "Max Temperature": temperature_max,
                           "Cloudiness": cloudiness,
                           "Wind Speed": wind_speed})

#Export the city data into a .csv.
weatherpy_df.to_csv("cities.csv")

# %%
weatherpy_df.head()
# Out:
#           City  Latitude  Longitude  Humidity  Max Temperature  Cloudiness  \
# 0        Jilin     43.84     126.54        49             6.29          76
# 1       Touros     -5.20     -35.46        94            26.00          40
# 2        Avera     33.19     -82.53        59            16.00           1
# 3     Hermanus    -34.42      19.24        96            18.33          44
# 4  Provideniya     64.42    -173.23        93             0.69          88
#
#    Wind Speed
# 0        2.75
# 1        1.50
# 2        2.40
# 3        1.15
# 4        7.00

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a scatter plot 
weatherpy_df.plot(kind="scatter", x="Latitude", y="Max Temperature", marker='o', grid=True, figsize=(12,6),
              linewidths = 0.80, edgecolors = 'black', color = 'green', s=60)

plt.title("City Latitude vs. Max Temperature (03/29/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#Save Figure
plt.savefig("images/latVStemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot 
weatherpy_df.plot(kind="scatter", x="Latitude", y="Humidity", marker='o', grid=True, figsize=(12,6),
              linewidths = 0.80, edgecolors = 'black', color = 'green', s=60)

plt.title("City Latitude vs. Humidity - 03/29/2019")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

#Save Figure
plt.savefig("images/latVShumi.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot 
weatherpy_df.plot(kind="scatter", x="Latitude", y="Cloudiness", marker='o', grid=True, figsize=(12,6),
              linewidths = 0.80, edgecolors = 'black', color = 'green', s=60)

plt.title("City Latitude vs. Cloudiness - 03/29/2019")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#Save Figure
plt.savefig("images/latVScloud.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot 
weatherpy_df.plot(kind="scatter", x="Latitude", y="Wind Speed", marker='o', grid=True, figsize=(12,6),
              linewidths = 0.80, edgecolors = 'black', color = 'green', s=60)

plt.title("City Latitude vs. Wind Speed - 03/29/2019")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
#Save Figure
plt.savefig("images/latVSwind.png")

# Show plot
plt.show()
